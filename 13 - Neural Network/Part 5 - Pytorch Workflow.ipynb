# %%
from luwiji.neural_network import illustration, demo
# Out:
# c:\Users\Toko Ferdi\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\random.py:42: UserWarning: Failed to initialize NumPy: module compiled against API version 0x10 but this version of numpy is 0xf (Triggered internally at ..\torch\csrc\utils\tensor_numpy.cpp:77.)
#   return default_generator.manual_seed(seed)

# %% [markdown]
# # Pytorch was meant to be flexible
# jadi tidak ada workflow yang saklek dan dikembalikan ke masing-masing orang <br> berikut workflow yang disarankan atau digunakan untuk kasus standar <br>
# - siapkan dataset dan dataloader
# - bangun arsitektur
# - ptersiapan training -> mco
# - Training Loop

# %% [markdown]
# # Sample Data

# %%
import numpy as np
from sklearn.model_selection import train_test_split

X = np.random.randn(1000, 1)
y = 2 * X + 3 + np.random.randn(1000, 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((800, 1), (200, 1), (800, 1), (200, 1))

# %% [markdown]
# # Step 1: Dataset & Dataloader

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
train_set = TensorDataset(X_train, y_train)
test_set = TensorDataset(X_test, y_test)

# %%
train_set.tensors
# Out:
# (tensor([[ 8.4071e-01],
#          [ 7.7644e-01],
#          [-1.3490e+00],
#          [ 1.6021e+00],
#          [-1.1880e+00],
#          [-8.5426e-01],
#          [ 8.5462e-01],
#          [ 7.1778e-01],
#          [-8.4050e-02],
#          [-2.7179e+00],
#          [-1.3687e+00],
#          [ 1.6303e-01],
#          [-2.1315e-01],
#          [ 1.3077e+00],
#          [-1.5266e+00],
#          [ 1.5579e+00],
#          [ 1.7020e-01],
#          [ 2.7534e-01],
#          [ 4.4907e-02],
#          [-8.5949e-01],
#          [ 7.2007e-01],
#          [ 1.0992e+00],
#          [ 1.1393e-01],
#          [ 6.2984e-01],
#          [-3.0242e-01],
#          [ 1.0846e+00],
#          [ 5.8529e-01],
#          [-9.3512e-01],
#          [ 3.0165e-01],
#          [-1.6573e+00],
#          [-1.3659e+00],
#          [-2.3589e-01],
#          [-1.0022e+00],
#          [-3.3953e-01],
#          [-5.7794e-01],
#          [ 5.5582e-01],
#          [-9.6458e-01],
#          [-6.4543e-01],
# ...
